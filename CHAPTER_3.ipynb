# %% [markdown]
# <a href="https://colab.research.google.com/github/NeonLabs146/Samsung-Innovation-Campus/blob/main/CHAPTER_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Chapter 3: Effective Python Programing - Function, Closure and Class**

# %% [markdown]
# ## **Unit 17: Functions**

# %% [markdown]
# - A function is a set of codes that performs a specific operation within a program. It has the characteristic of being executed when it is called.
# - A function is the basic building block of a program.
# - The software we use is made by combining various functions and modules.
# - Think about assembling Lego blocks to create the shape you want. It is the same for making programs. To make a large program with more than tens of thousands of code lines, the necessary functions must be well combined and arranged in order.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def print_star():
    """
    Simple function that outputs asterisk
    """
    print("********************")

# call the function to print asterisk
print_star()

# %%
# Need to print it 4 times
print_star()
print_star()
print_star()
print_star()

# %% [markdown]
# ### Function parameter
# ![image.png](data:image/png;base64,...)

# %%
def print_sum(a, b):
    result = a + b
    print("The sum of", a, "and", b, "is", result)

# %%
print_sum(10, 20)
print_sum(100, 200)

# %%
# if we pass incorrect number of arguments, we will get an error
print_sum(10)

# %%
# Asterisk output function with parameters
def print_star(n):
    for i in range(n):
        print("******************")

# %%
print_star(2)

# %%
def print_hello(n):
    print("Hello " * n)

print("It prints Hello 2 times")
print_hello(2)

print("It prints Hello 3 times")
print_hello(3)


print("It prints Hello 4 times")
print_hello(4)

# %% [markdown]
# **What if we need to send an arbitary number of arguments**
#
# - there might be cases where the number of input parameters are not fixed
#
# eg:
#
# ```
# max(10, 20, 30, ...)
# ```
# - When receiving an arbitrary argument from a function, put an asterisk (*) in front of the parameter. A variable inside a function that receives an arbitrary argument is an arbitrary parameter.
#
#
# ![image.png](data:image/png;base64,...)

# %%
def _name(*name):
  for i in name:
    print("hello", i)

_name("a",'b')

# %%
def foo(*args):
    print("The number of arguments:", len(args))
    print("Arguments:", args)
    # what is the type of args?
foo(10, 20, 30, 50)

# %%
def sum_nums(*numbers):
    result = 0
    for n in numbers:
        result += n
    return result
print(sum_nums(10, 20, 30))
print(sum_nums(10, 20, 30, 40, 50))

# %% [markdown]
# ### Default Parameters

# %%
def print_star(n):
    for _ in range(n):
        print("********************")
print_star()

# %%
# Hassel to pass 1 as value if that is the defautl behaviour you expect to be handeled
def print_star(n=1):
    for _ in range(n):
        print("********************")
print_star()

# %%
def div(a, b=2):
    return a/b

print("div(4) = ", div(4))
print("div(6, 3) = ", div(6, 3))

# %%
# non-default arguments cannot follow default argument
def div(a=2, b):
    return a/b

# %%
def div(a=1, b=2):
    return a/b

print("div() = ", div())
print("div(4) = ", div(4))
print("div(6, 3) = ", div(6, 3))

# %% [markdown]
# ### Keyword Parameter

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - When calling a function, instead of passing only the value of the argument, the method of passing the argument by specifying the name is called a keyword parameter.
# - In the code below, if -8, 2, 1 is given as an argument, the result is different from when 1, 2, -8 is given as an argument.

# %%
def get_root(a, b, c):
    r1 = (-b + (b ** 2 - 4*a*c)**0.5) /(2*a)
    r2 = (-b - (b ** 2 - 4*a*c)**0.5) /(2*a)
    return r1, r2

result1, result2 = get_root(1, 2, -8)
print("the result is", result1, "or", result2)

# %%
result1, result2 = get_root(-8, 2, 1)
print("the result is", result1, "or", result2)

# %%
# we can instead do this:

result1, result2 = get_root(a=1, b=2, c=-8)
print("the result is", result1, "or", result2)

result1, result2 = get_root(a=1, c=-8, b=2)
print("the result is", result1, "or", result2)

result1, result2 = get_root(b=2, c=-8, a=1)
print("the result is", result1, "or", result2)

# result of all 3 are same, the position of the argument is not important

# %%
# positional argument however cannot folow keyword argument
result1, result2 = get_root(a=1, b=2, -8)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
result1, result2 = get_root(1, 2, c=-8)

# %% [markdown]
# ### Return
#
# ![image.png](data:image/png;base64,...)

# %%
def get_sum(a, b):      # A function that returns the sum of two numbers
    return a + b        # Return the result using the return statement

result = get_sum(100, 200)
print("The sum of two numbers", result)

# %%
# Returning multiple values as tuple

def

# %% [markdown]
# #### String Processing methods
#
# Code and explore the following methods in a sting
#
# - count
# - len
# - max
# - min
# - ord
# - chr
# - count
# - find
# - startswith
# - endswith
# - upper
# - lower
# - swapcase
# - istitle
#
# Q: How can we find all the lowercase and uppercase alphabets in the

# %%
birth = "1998.05.13"
print("count of . =", birth.count("."))
print("length of birth = ", len(birth))
print("Max value = ", max(birth))
print("Min value = ", min(birth))
print("Unicode value of max = ", ord(max(birth)))
print("Unicode value of min = ", ord(min(birth)))
print("Character associated with unicode values 57 and 46 are :", (chr(57), chr(46)))

# %%
a = "I love python"
print("count of o: ", a.count("o"))
print("count of k: ", a.count("k"))
print("find `o` in a: ", a.find("o"))
print("find `on` in a: ", a.find("on"))
print("Does a start with `I`:", a.startswith("I"))
print("Does a end with `python`:", a.endswith("python"))
print("Upper case: ", a.upper())
print("lower case: ", a.lower())
print("swap case: ", a.swapcase())
print("Is it a title case case: ", a.istitle())

# %%
import string
string.ascii_uppercase, string.ascii_lowercase

# %% [markdown]
# #### CE 1:
#
# Write a function to calculate the area and circumference of a circle. It will take radius as input and return the area and circumference as tuple
#
# ```python
#
# def circle_area_circum(radius):
#     ...
#     return area, circum
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Functions and Methods**
# 1. Function – A module in programming that receives parameters (optionally ignored) when called, performs a specific
# operation, and returns the result if necessary.
# 2. Method - A function attached to an object dealt with in object-oriented programming.
# *A method can call objects with different values, called instances.*

# %% [markdown]
# ### PP1
# Let the user input three integers a, b, and c. And print the average, maximum, and minimum values of these three numbers as follows.
#
# In this case, mean3(a, b, c), max3(a, b, c), min3(a, b, c) that takes three numbers as parameters and returns the average, maximum, and minimum values of these three numbers. Define and call each function.
#
# Output Example
# ```
# Enter three numbers : 9 2 6
# The average value of 9, 2, 6 is 5.666666666666667
# The maximum value of 9, 2, 6 is 9
# The minimum value of 9, 2, 6 is 2
# ```

# %% [markdown]
# **Product Set**
# 1. Learn a product set, the advanced topic of sets discussed in the previous section.
# 2. Let's see how to easily create a product set using a function.
#
# #### The product set of two sets A and B, denoted as A × B, is the set of all ordered pairs (a, b) where a belongs to A and b belongs to B. In other words, the product set of A and B contains all possible combinations of one element from A and one element from B. For example, if A = {1, 2} and B = {3, 4}, then A × B = {(1, 3), (1, 4), (2, 3), (2, 4)}.
# ####Note that the order of elements in the ordered pairs matters. Thus, (a, b) is not the same as (b, a) unless a = b. The product set is useful in defining operations and relations between elements of two sets.

# %% [markdown]
# The above operation can be implemented by repeating the product_set function.

# %% [markdown]
# #####**Find the set of products using a function.**
# #####Review the product set discussed in the key concept of the previous unit once more.

# %%
#@title
def product_set(set1, set2):
	res = set()
	for i in set1:
		for j in set2:
			res = res | {(i, j)} 	              #Product set using double loop
	return res

def exp(input_set, exponent):	            #A function that performs power on input_set
	res = input_set	          	            #res initialization
	for _ in range(exponent-1):	          #Repeated for (exponent-1) to become a power
		res = product_set(res, input_set)
	return res

A = {1, 3}
A3 = exp(A, 2)                            #Performs 3 power on A
print(A3)

# %% [markdown]
# Line 15: When an argument is passed in the exp function, exp calls product_set to perform a multiplication set. That is, the
# third power is performed.

# %% [markdown]
# **The number of all possible outcomes when a die is rolled twice**

# %% [markdown]
# •Use the product_set function to count the number of cases in which a dice is rolled twice.

# %%
def product_set(set1, set2):
	res = set()
	for i in set1:
		for j in set2:
			res = res | {(i, j)} 	#Product set using double loop
	return res

case1 = {1,2,3,4,5,6}
#case2 = {3,4}
#case_new = product_set(case1,case2)
#print(case_new)
case1_2times = product_set(case1,case1)
print(case1_2times)

# %% [markdown]
# **Line 8, 9**
# 1. The cases variable is assigned as a set type from 1 to 6.
# 2. Multiply the two cases. Then, the combination of two numbers is assigned as a set type. All cases are returned
# without duplicates.

# %% [markdown]
# ## Unit 18: Recursion Function Call

# %% [markdown]
# - A recursion is a function that calls itself inside a function. Recursion is a very useful troubleshooting technique. It can intuitively and simply solve problems that are difficult to solve with procedural techniques.
# - Factorial expression and definition : n! = n * (n – 1)!, if n <= 1 : return 1
#
#
# ![image.png](data:image/png;base64,...)

# %%
def factorial(n):
    if n <= 1:
        return 1
    else:
        return n * factorial(n-1)
n = 10
print('{}! = {}'.format(n, factorial(n)))

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

for i in range(11):
  print(fibonacci(i), end=' ')

# %%
# %%timeit -n 1 -r 20

fibonacci(30)

# %% [markdown]
# #### Memoization
#
# -
#
# ![image.png](data:image/png;base64,...)

# %%
# %%timeit -n 1 -r 20

memo = {0:0, 1:1}

def fibonacci_2(n):
    if n in memo:
        return memo[n]
    memo[n] = fibonacci_2(n-1) + fibonacci_2(n-2)
    return memo[n]
fibonacci_2(30)
print(memo)

# %% [markdown]
# ### Built-in functions
#
# ![image.png](data:image/png;base64,...)

# %%
# using builtin funciton example
print(abs(-10))                 # A function that returns an absolute value
print(max(1, 3, 4, 5, 0, -1))   # A function that returns the minimum value among multiple elements
print(min(1, 3, 4, 5, 0, -1))   # A function that returns the maximum value among multiple elements

# %%
str1 = "FOO"
len(str1), type(str1), id(str1)

# %%
eval("100 + 100 + 300")

# %%
sorted("EABFD")

# %%
n_list = [200, 100, 300, 400, 50]
sorted(n_list)

# %%
sorted(n_list, reverse=True)

# %% [markdown]
# ### PP 2
#
# The natural number e, also called Euler's number or Napier's constant, is an irrational number used as the base of the natural logarithm. It is defined by the following formula.
#
# ( e = 1 + 1/1! + 1/2! + 1/3! + ..... + 1/n! )
#
# In this formula, let k! be defined as a function named factorial(k). Also, let's define a function called euler(n) that returns the sum of 1/0! + 1/1! to 1/n! Find the value of euler(20) to five decimal places and output it as follows. (You must use a recursive function.)
#
# **Example Output:**
#
# ```
# eular(20) =	2.71828
#
# ```

# %%
#@title
def factorial(n):
  fact = 1
  if n < 1:
    return 1
  else:
    fact = n*factorial(n-1)
    return fact

x = int(input("Enter the euler number: "))
euler_sum = 1
for i in range(1,x+1):
  #n = factorial(i)
  #print(n)
  euler_sum+=1/(factorial(i))
print(f"The euler ({x}) = {euler_sum}")

# %% [markdown]
# ## Unit 19: Lambda

# %% [markdown]
# ### Lambda expression
#
# syntax:
#
# ``` python
# lambda parameters: expression
# ```
# ![image.png](data:image/png;base64,...)

# %%
def add(x, y):
    return x + y

add(9, 2)

# %%
# !! assigning is not good practice
add=lambda x, y: x+y
add(9, 2)

# %% [markdown]
# ### **filter, map and reduce**

# %% [markdown]
# ### **filter**
#
# ![image.png](data:image/png;base64,...)

# %%
ages = [34, 39, 20, 18, 13, 54]

# we want to find the ages above 18 only

# %%
def adult_func(n):
    if n > 18:
        return True
    else:
        return False

print("Adults list:")
for a in filter(adult_func, ages):
    print(a, end=" ")

# %%
for a in filter(lambda x: x >=19, ages):
    print(a, end=" ")

# %%
filter(lambda x: x>=19, ages)

# %%
list(filter(lambda x: x>=19, ages))

# %% [markdown]
# ## **map**
#
# **syntax:**
#
# ```python
# map(function_to_be_applied, iterable_object, ...)
# ```

# %%
a,b= map(int,input("numbers").split(","))
print (b,a)

# %%
def square(x):
    return x ** 2

a = [1, 2, 3, 4, 5, 6, 7]
square_a = list(map(square, a))
square_a

# %%
# Combining map and lambda function

a = [1, 2, 3, 4, 5, 6, 7]
square_a = list(map(lambda x: x**2, a))
square_a

# %%
# can take multiple iterable.. will loop over each one as far as possible
list(map((lambda x, y: (x, y)), [1, 2, 3], [4, 5, 6, 8]))

# %%
# map returns a object of type map..
map(lambda x: x**2, a)

# %% [markdown]
# #### reduce
#
# ![image.png](data:image/png;base64,...)

# %%
from functools import reduce

a = [1, 2, 3, 4]
n = reduce(lambda x, y: x+y, a)
print(n)

# %% [markdown]
# ### Exception Handling

# %%
# some code raise exception
a, b = input().split()
a=int(a)
b=int(b)
c = a/b
print(c)

# %%
a, b = 4, 0
try:
    c = a/b
    print(c)
except:
    print("Check if the numbers are incorrect")

# %%
# You can know the type of exception as follows:
try:
    b= 2/ 0
    a = 1 + "hundred"
except Exception as e:
    print("error", e)

# %% [markdown]
# - A sophisticated exception handling as the following is possible by using try -  except – else – finally.
#
#
# ![image.png](data:image/png;base64,...)

# %%
def divide(x, y):
    try:
        result = x/y
    except ZeroDivisionError:
        print("error by zero division")
    else:
        print("result: ", result)
    finally:
        print("execution complete")

print("divide(100, 2) function call")
divide(100, 2)
print("divide(100, 0) function call")
divide(100, 0)

# %% [markdown]
# #### Various exceptions in Python
# ![image.png](data:image/png;base64,...)

# %%
#typeerror
num = 5
message = "The number is " + num

# %%
my_dict = {"apple": 2, "banana": 3, "orange": 4}
my_dict["grapes"]
print(my_dict)
if "grapes" in my_dict:
    print(my_dict["grapes"])
else:
    print("The key 'grapes' does not exist in the dictionary.")

# %% [markdown]
# Alternatively, you can use the get() method of a dictionary, which returns None (or a default value that you can specify) if the key is not found:

# %%
my_dict.get("apple", "The key 'apple' does not exist in the dictionary.")

# %% [markdown]
# A KeyError in Python is raised when you try to access a dictionary key that does not exist.

# %% [markdown]
# ### Iterator object
#
# ![image.png](data:image/png;base64,...)

# %%
iter_a = iter([10, 20])
next(iter_a)

# %%
next(iter_a)

# %%
next(iter_a)

# %%
# objec needs to be iterable to use iter

n = 100 # Non iterable data
n_iter = iter(n)

# %% [markdown]
# ### **CE 2: Use try excep to check if a object is iterable or not.**
#
# ###Use the code to check if list, tuple, int, range are iterable or not

# %%
def is_iterable(obj):
    try:
        iter(obj)
        return True
    except TypeError:
        return False

# test the function with various objects
print(is_iterable('hello'))
print(is_iterable([1, 2, 3]))
print(is_iterable((1, 2, 3)))
print(is_iterable(123))  # False, integer is not iterable
print(is_iterable({'a': 1, 'b': 2}))  # True, dictionary is iterable (iterates over keys)
print(is_iterable(x for i in range(4)))

# %% [markdown]
# #### all and any

# %%
l1 = [1, 2, 3, 4]
l2 = [0, 2, 4, 8]
l3 = [0, 0, 0, 0]

all(l1), all(l2), all(l3)

# %%
any(l1), any(l2), any(l3)

# %%
# Thanks mathematics/ philosophy
all([]), any([])

# %%
def prime(n):
  primes = []
  for num in range(2, n+1):
    #is_prime = True
    for i in range(2,int(num**0.5)+1):
      if (num%i==0):
        #is_prime = False
        break
    #if is_prime
    else:
        primes.append(num)
  return primes

print(prime(20))

# %%
#@title
def generate_prime_numbers(n):
    primes = []
    for num in range(2, n+1):
        if all(num%i!=0 for i in range(2,num)):
           primes.append(num)
    return primes

print(generate_prime_numbers(20))

# %% [markdown]
# ### **List comprehension**
# - The syntax of the list comprehension is as follows.
#
# `[{expression} for {variable} in {iterator/ sequence} if {condition}]`
#
# - The if conditional expression can be omitted in the list comprehension.
#
# `[{expression} for {variable} in {iterator/ sequence}]`

# %%
ages = [34, 39, 20, 18, 13, 54]
adult_ages = [x for x in ages if x>=19]
print(adult_ages)

# %%
a = [1, 2, 3, 4, 5, 6, 7]
list(map(lambda x: x**2, a))

# %%
a = [1, 2, 3, 4, 5, 6, 7]

[x**2 for x in a]

# %%
ages = [34, 39, 20, 18, 13, 54]
adult_ages = list(filter(lambda x: x>=19, ages))
print(adult_ages)

# %% [markdown]
# #### CE 3
#
# Use list comprehension to get the following:
#
# - list of numbers from 0 to 9
# - square values of numbers from 0 to 9
# - value of even numbers from 0 to 9
# - value of odd numbers from 0 to 9
# - square values of even numbers from range 0 to 9
# - square values of odd numbers from range 0 to 9

# %%
print([x for x in range(10)])
print([x*x for x in range(10)])
print([x for x in range(10) if x %2 == 0])
print([x for x in range(10) if x %2 == 1])
print([x*x for x in range(10) if x %2 == 0])
print([x*x for x in range(10) if x %2 == 1])

# %%
Codes = ['Pyhton', 'C', 'C++', 'Java', 'Php', 'Javascript']
[code for code in Codes if code.startswith('P')]

# %%
Brand =['Apple', 'Samsung', 'Hitachi','Lenovo', 'Philips', 'Amazon']
Daraz =['Apple', 'Samsung', 'Oppp', 'Xaomi', 'Silicon', 'Artic']
[assets for assets in Brand if assets in Daraz]

# %%
[assets for assets in Brand if assets in Daraz if assets.startswith('A')]

# %% [markdown]
# ###**Comparison of List Comprehension and Lambda Expression**

# %%
s=input("Enter the list of integers:").split()
lst = [int(x) for x in s]
lst

# %%
lst = [int (x) for x in input("Enter the list of integers:").split()]
lst

# %% [markdown]
# This code generates a new list by multiplying two lists. It used the double for loop.

# %%
lst_multiply = []
for x in [1,2,3,4]:
  for y in [7,8,9]:
    lst_multiply.append(x*y)
print(lst_multiply)

# %% [markdown]
# Above code can be condensed into a one-line code by using a list comprehension.

# %%
lst_multiply =[x*y for x in [1,2,3,4] for y in [7,8,9]]

print(lst_multiply)

# %% [markdown]
# #####**Application of list comprehension and lambda expression**
# #####EX: Computing multiple of 2 and 3 by using list comprehension and lambda expression

# %%
[n for n in range(1,31) if n%2==0 if n%3==0]

# %%
list(filter(lambda x:(x%2==0 and x%3==0), range(1,31)))

# %%
list(filter(lambda x:(x%2==0 and x%3==0 and x%5==0), range(1,31)))

# %% [markdown]
# ### PP 3
# If you treat students’ scores of English, math, and science exams as list of three elements, it can be expressed as a list such as `[100, 90, 95]`. If there are two students, their scores can be expressed as `[100, 90, 95, 90, 85, 93]`. If a student did not apply to the exam of a certain subject, denote that score as 0. Print how many students’ scores are contained in the given scores list, the number of students with valid scores for all subjects (that is students with no 0 for all subject), and the scores of students with only valid scores.
#
# **Example Input**
#
#
# ![image.png](data:image/png;base64,...)
#
# **Example Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
#@title
scores = [
    [100, 90, 95, 90, 85, 93],
    [80, 85, 90, 0, 95, 87],
    [70, 75, 80, 85, 90, 0],
    [95, 85, 90, 80, 75, 85],
    [0, 90, 85, 95, 80, 90]
]

num_students = len(scores)
print("Number of students:", num_students)

valid_scores = [s for s in scores if all(subscore != 0 for subscore in s)]
num_valid_students = len(valid_scores)
print("Number of students with valid scores for all subjects:", num_valid_students)

print("Scores of students with only valid scores:")
for s in valid_scores:
    print(s)

# %%
# @title
lst = [90,0,80,88,90,99,78,87,89,80,0,78,85,90,95]

new_lst = []
in_lst = []

for i in range(len(lst)):
    if i % 3 == 0 and i != 0:
        new_lst.append(in_lst)
        in_lst = []
    in_lst.append(lst[i])

new_lst.append(in_lst)

print(new_lst)

# %%
# @title
lst = [90,0,80,88,90,99,78,87,89,80,0,78,85,90,95]
new_lst = []
for i in range(0,len(lst),3):
  new_lst.append(lst[i:i+3])
print(new_lst)

# %%
#@title
scores = [90,0,80,88,90,99,78,87,89,80,0,78,85,90,95]

new_score_lst = [lst[i:i+3] for i in range(0,len(lst),3)]

print(new_score_lst)

num_students = len(new_score_lst)
print("Number of students:", num_students)

valid_scores = [s for s in new_score_lst if all(subscore != 0 for subscore in s)]
print("Number of students with valid scores for all subjects:", len(valid_scores))

print("Scores of students with only valid scores:")
for score in valid_scores:
    print(score)

# %% [markdown]
# ## Unit 20: Closure

# %% [markdown]
# ###**Python’s scoping rule**

# %% [markdown]
# ###Scope rule
# 1. This unit introduces many high-level functions and abstract concepts.
# 2. This unit focuses on examining the valid scope of variables or function names.
# 3. Programming languages including Python sets a rule on scope of access and valid context for a variable, and this is
# called the Scope Rule.
# 4. Python distinguishes the scope of variables as follows:
#   1. L(Local) : a local variable defined within a function
#   2. E(Enclosing Function Local): a scope of a function that contains another function.
#   Python, unlike other programming languages, can define a function inside a function (inner function).
#   3. G(Global): a variable of a module-level namespace that is not included in the scope of the function.
#   4. B(Built-in): a variable of the built-in namespace.

# %%
x = 10
y = 11

def foo():
    x = 20
    def bar():
        a = 30
        print(a, x, y)
    bar()
    x = 40
    bar()

foo()
print(x)

# %%
# global abs function
abs(-5)

# %%
abs = 10

# %%
abs

# %%
abs(-5)

# %%
del abs

# %%
abs(-5)

# %%
def print_counter():
    counter = 200
    print("counter =", counter)

counter = 100
print_counter()
print("counter =", counter)

# %%
def func():
    n2 = 1
    def func2():
        print(n2)
    func2()
func()

# %%
def func():
    n2 = 1
    def func2():
        n2 += 1
        print(n2)
    func2()
func()

# %%
def func():
    n2 = 1
    def func2():
        nonlocal n2
        n2 += 1
        print(n2)
    func2()
func()

# %%
x = 1

def func():
    def func2():
        nonlocal x
        x += 1
        print(x)
    func2()

func()

# %% [markdown]
# ### **Closure**

# %% [markdown]
# A closure is a nested function that remembers and has access to the values of the enclosing function's variables, even after the enclosing function has completed execution.

# %% [markdown]
# The basic form of a closure function is as follows. It creates an nested function inside a function and returns the nested function as a return value.
# - Here you can say that the nested function ‘was closured.’ If the function is closured, the variable inside the body of the original function (outer function) does not disappear from the memory. Then, in the next call it can utilize the nested function.
# - Study the concept of the closure with the following code.
# - What are free variables? A free variable is only used in a certain code block, but it is not a global variable, and it is not defined within the block. It is a relative concept.
# - That is, in the point of view of mult function, a is a free variable. However, for closure-calc, a is only a local variable.

# %%
def outer_func(x):
    def inner_func(y):
        return x + y
    return inner_func

closure_func = outer_func(20)
print(closure_func(30))

# %%
def add_constant(c):
    def adder(x):
        return x + c
    return adder
add_five = add_constant(5)
add_ten = add_constant(10)

print(add_five(3))
print(add_ten(3))

# %%
def closure_calc():
    a = 2
    def mult(x):
        return a * x
    return mult

c = closure_calc()
print(c(1), c(2), c(3))

# %% [markdown]
# #### Usage of Closure
#
# 1. Limiting usage of global variables
# 2. Data hiding
#
#
# - A closure has a separate memory for each variable.
#
#
# ![image.png](data:image/png;base64,...)

# %%
def makecounter():
    count = 0

    def counter():
        nonlocal count
        count += 1
        return count
    return counter

c1 = makecounter()
c2 = makecounter()
print("c1", c1())
print("c1", c1())
print("c2", c2())
[print(c1()) for x in range(1,10)]

# %% [markdown]
# ### Closure with Lambda

# %%
def closure_calc():
    a = 2
    b = 3
    return lambda x: a * x + b
c = closure_calc()

print(c(1), c(2), c(3), c(4), c(5))

# %% [markdown]
# ### Change Local Variable of Closure
#
#
# *   Use the nonlocal to change the local variable of a closure

# %%
def calc():
    a = 2
    b = 3
    total = 0
    def mult_add(x):
        nonlocal total
        total = total + a * x + b
        return total
    return mult_add
c = calc()
print(c(1), c(2), c(3))

# %% [markdown]
# ##**ZIP**
# ####return the zip object, which is an iterator of tuples where the first item in each passed iterator is paired together, and then the second item in each passed iterator are paired together etc.
#
# ####If the passed iterables have different lengths, the iterable with the least items decides the length of the new iterator.
#
# #####Syntax: zip(iterator1, iterator2, iterator3 ...)

# %%
a = ("Ram", "Hari", "Mohan")
b = ("sita", "Gita", "Rita", "Vini")

x = zip(a, b)
print()
print(list(x))

# %%
a = [1,2,3]
b = [4,5,6]

# %%
[a+b for i,j in zip(a,b)]

# %% [markdown]
# ### Turtle graphics

# %%
import turtle as t
#t.Turtle()
t.setup(width=400, height=400)

for i in range(200):
    t.forward(i)
    t.left(93)
t.done()

# %% [markdown]
# **Different Turtle commands**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Regular Expressions and Meta Characters

# %%
import re

txt1 = "Life is too short, you need python 99."
txt2 = "The best moments of my life."

print(re.search("Life", txt1))

print(re.search("Life", txt2))

# %%
# The first case is returning match object lets have a look at it

text_match = re.search("Life", txt1)
text_match.group()

# %%
text_match.start(), text_match.end(), text_match.span()

# %%
txt1[0:4]

# %% [markdown]
# #### Searcing with regular expression:
#
# - In case of a text string as follows, the compile function of the re module searches regular expression patterns and compiles them to regular expression objects.
# - Then, a regular expression object called regex is created, and this object searches text with a given pattern.
# - \d{3} finds patterns of 3 integers. \d{4} finds patterns of 4 integers. The bracket places these patterns into group 1 and group 2.

# %%
import re

text = 'please call 010-2345-1234'
# has two groups (\d{3}) and (\d{4}-\d{4})
regex = re.compile('(\d{3})-(\d{4}-\d{4})')
match_obj = regex.search(text)

# the first one is the whole search
print(match_obj.group())

# %%
print(match_obj.group(1))
print(match_obj.group(2))

# %% [markdown]
# #### Meta characters
# **Essential Meta characters**
#
# Regular expression | Function | Description
# ---|---|---
# ^| start | Matches the start of the string
# $| end | Matches the end of the string
# .| character | Matches one character
# \d| number | Matches one number
# \w| character or number | Matches one character or one number
# \s | whitespace characters | Matches a space, a tab, a carriage return and a line feed
# \S| Except whitespace characters| Matches one non whitespace character
# *| repetition | 0 or more repetition
# +| repetition | 1 or more repetition
# \[abc] | chracter range| displays a or b or c
# \[^abc]| character range| is any character that is not a or b or c

# %%
# Since Life or life share the same characters except for the first l, the following expression returns the same result.
print(re.search('[Ll]ife',txt2))

# %%
print(re.match("^Life", txt1))
print(re.match("^Life", txt2))

# %%
txt1 = "Who are you to judge the life i live"
txt2 = "the best moments of my life"
print(re.search("life$", txt1))
print(re.search("life$", txt2))

# %%
import re
print(re.search('A..A','ABA'))
re.search('A..A','ABBA')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
re.search("AB?", "A")

# %%
re.search("AB?", "CCABABDD")

# %%
txt3 = "My life my life my life in the sunshine"
re.findall("[Mm]y", txt3)

# %% [markdown]
# **r'...' denotes raw strings which ignore escape code**

# %%
import re
re.findall(r'[0-9]+', 'abc678xyz')

# %%
re.findall(r'\d', 'abc00-123-xyz456_0')

# %%
re.findall(r'\d+', 'abc00-123-xyz456_0')

# %% [markdown]
# ### PP 3
# Extract list result from list lst which has values of 1 ~ 100. list result has elements of list lst that are divisible by 5 or 7. Declare func1(a) function and nest func2 and func3 function. Then, call the two functions in func1 function and print numbers divisible by 5 or 7. Here, align the values by using the sorted () function.
#
#
# ![image.png](data:image/png;base64,...)

# %%
#@title
def fun1(a):
  def fun2():
    result1 = []
    for i in a:
      if i % 5 ==0:
        result1.append(i)
    return result1
  def fun3():
    result2 = []
    for i in a:
      if i % 7 ==0:
        result2.append(i)
    return result2

  result = fun2() + fun3()
  #result.sort()
  return result


list1 = [x for x in range(1, 101)]
#print(list1)
x = fun1(list1)
print(x)

# %%
#@title
lst = [i for i in range(1, 101)]  # list of values 1 ~ 100

def func1(a):
    def func2(x):
        return x % 5 == 0  # returns True if x is divisible by 5
    def func3(x):
        return x % 7 == 0  # returns True if x is divisible by 7

    result = []
    for x in a:
        if func2(x) or func3(x):
            result.append(x)
    result = sorted(result)
    print(result)

func1(lst)  # call func1 with list lst

# %% [markdown]
# ## **Unit 21 Class**

# %%
animal = ['Tiger', 'Lion', 'Cat', 'Dog', 'Elephant']
animal.sort()
animal

# %%
import numpy as np
a = np.array([1,2,3,4])
b = np.array([1,4,5,6])

c = np.intersect1d(a,b)
print(c.sum())

# %% [markdown]
# animal object with attributes Tiger, Lion, ...etc.

# %%
animal.append('Rabbit')
animal`

# %% [markdown]
# ####methods are called using (.) dot operator.
# sort(), append() etc.
# ####methods are the member functions.

# %% [markdown]
# ##**1.2. Comparison of procedural programming and object-oriented programming**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**1.3. Syntax for calling Python’s objects and methods**

# %% [markdown]
# Use .(dot) operator to call methods for an object.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'Tiger'.upper()

# %%
s=animal.pop()
s

# %%
s.find('i')

# %% [markdown]
# **Everything in Python is an object.**

# %% [markdown]
# ###**Defining instances and objects**

# %% [markdown]
# 1. **Class:**
# ####An abstract concept that denotes a set of attributes and actions used in programs.
# ####A set of attributes and actions used in programs.
# ####A plan, template or blueprint of objects.
# 2. **Instance:**
# ####An individual object created from a class. It has specific attribute values.
# ####An individual object created from a class.
# ####Different instances can have different attribute values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Syntax for class definition**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Declaring Class, and Constructor and self Parameter**
# ###Constructor method **__ init__** and **__ str__**

# %% [markdown]
# ####**Constructor __ init__**
# 1. A method that assigns a default value to a variable inside an instance when creating an object.
# 2. Its name is __ int__.
# 3. Automatically executed when an object is generated.

# %% [markdown]
# ###**__ str__ method**
# 1. A method that displays the information of an object in string format.
# 2. An example within the Cat class : __ str__ method that displays the name and color of a cat.

# %% [markdown]
# ###**Class definition and __ init__, __ str__ special method**
# #####Add __ str__ method to the Cat class as shown below. This method is automatically called by the print function.
# •__ str__ method returns nicely printable string representation of an object.
# #####If you run print(nabi) to print the color and name of the cat, print(nabi.__str__()) is automatically called.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#@title
class cat:
  def __init__(self,name,color):
    self.name=name
    self.color=color
  def __str__(self):
    return 'Cat(name='+self.name+',color='+self.color+')'

nabi=cat('Nambi','Brown')
print(nabi)

# %% [markdown]
# ####This method’s first parameter self refers to the instances of the current class.
# ####The second parameter name and the third parameter color are variables that assign corresponding names and colors,
# which are instance attributes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**Structure of Method**
# ####Definition of method and exemplary code of calling method

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Class Variables and Methods**
# ###**What are instance variables?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**What are class variables?**
# ####•Class variables are defined outside the methods as shown below. This class variable PI is shared by instances c1, c2 and
# c3.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**__ dict__ which displays attribute information of class objects**
# #####You can convert the variable of the class object to a dictionary type.
# #####You can easily call attribute values by converting them to dictionary type.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Real World Problem**

# %%
class Bank_account:
  """A class example in python to model bank account"""
  def __init__(self, name, account_no, balance =0):
    self.name = name
    self.account_no = account_no
    self.balance = balance

  def get_name(self):
    return self.name

  def get_account_no():
    return self.account_no

  def get_balance():
    return self.balance

  def _deposit(self, amount):
    self.balance+=amount
    print('{} amount has been deposited to ypur account. Now your new balance is {} rupees'.format(amount,self.balance))

    return self.balance

  def _withdraw(self, amount):
    if self.balance-amount > 0:
      self.balance-=amount
    else:
      print(f'Your balance is {self.balance}, less than the withdrawal amount {amount}')
  def __str__(self):
    return 'The balance of {} is {} rupees with account no {}'.format(self.name,self.balance, self.account_no)

client1 = Bank_account("RAM", 198123, 9000)
client2 = Bank_account("Sita", 918765,8000)

print(client1.get_name())
print(client2.balance)
print(client1._deposit(2000))
print(client1)

# %% [markdown]
# ### `type` and `id` function

# %%
animals = ["lion", "tiger", "cat", "dog"]
type(animals)

# %%
id(animals)

# %%
s = "tiger"
type(s)

# %%
id(s)

# %%
# Simple assignment

animals = ["lion", "tiger", "cat", "dog"]
others = animals

print(id(animals), id(others), id(animals) == id(others))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **various special methdods**
#
# operator| special method| functionality
# ---|---|---
# **x + y**| **\_\_add\_\_**(self, other)| Computes the sum of x and y
# **x - y**| **\_\_sub\_\_**(self, other)| Computes the difference between x and y
# **x * y**| **\_\_mul\_\_**(self, other)| Computes the multiplication of x and y.
# **x ** y**| **\_\_pow\_\_**(self, other)| Computes x power y.
# **x / y**| **\_\_truediv\_\_**(self, other)| Computes x divided by y.
# **x // y**| **\_\_floordiv\_\_**(self, other)| Computes the quotient of x divided by y.
# **x % y**| **\_\_mod\_\_**(self, other)| Computes the remainder of x divided by y.
# **+x**| **\_\_pos\_\_**(self)| Gives x.
# **-x**| **\_\_neg\_\_**(self)| Gives negative x.
# **x < y**| **\_\_lt\_\_**(self, other)| Is x smaller than y?
# **x <= y**| **\_\_le\_\_**(self, other)| Is x smaller than or equal to y?
# **x > y**| **\_\_gt\_\_**(self, other)| Is x greater than y?
# **x >= y**| **\_\_ge\_\_**(self, other)| Is x greater than or equal to y?
# **x == y**| **\_\_eq\_\_**(self, other)| Are x and y equal?
# **x != y**| **\_\_ne\_\_**(self, other)| Are x and y not equal?

# %%
class _arithmetic:
    def __init__(self, value):
        self.value = value

    def __add__(self, other):
        if isinstance(other, _arithmetic):
            return _arithmetic(self.value + other.value)
        else:
            raise TypeError("Unsupported operand type: {} + {}".format(type(self), type(other)))
    def __sub__(self, other):
        if isinstance(other, _arithmetic):
            return _arithmetic(self.value - other.value)
x = _arithmetic(6)
y = _arithmetic(4)

result1 = x + y
result2 = x - y
print(result1.value, result2.value, sep = ',')

# %% [markdown]
#  ### **Necessity of special methods**

# %% [markdown]
# •Construct a class named Vector 2D that expresses two-dimensional vectors and observe the necessity of special
# methods in this class. Why does v1 + v2 produce an error in the code below?

# %%
class Vector2d:
  def __init__(self,x,y):
    self.x=x
    self.y=y

v1=Vector2d(30,40)
v2=Vector2d(10,20)
v3=v1+v2                #+ operator is not defined in Vector2D
print("v1+v2 = ", v3)

# %% [markdown]
# •The reason for the error is because the code does not state how the class will operate additions within.
# •Define a method named add as follows and add the x component and y component of the two vectors. Then,
# return a Vector2D that has values of these components as the initial value.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Class and Inheritance**
#
# Inheritance in python can be done as follows where class B is inheriting from class A
#
# ```
# class A:
#     ...
#
# class B(A):
#     ...
#
# ```
#
# **Class of hierarchical structure:**
# - Examine the class with hierarchical structure below.
# - You can construct class Manager that means manager and class Employee that means employee by inheriting the class Person, which is the parent class.
# - Since managers and employees are both human-beings, the two child classes should contain the name attribute and get_name() method from the Person class.
# - If the class Manager and the class Employee inherit the class Person, the two classes will contain the member variables and member functions of the class Person without any extra coding.
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
 class Person:
    def __init__(self, name):
        self.name = name
    def get_name(self):
        return self.name

class Employee(Person):
    """
    Child class of person class
    """
    def __init__(self, name, staff_id):
        Person.__init__(self, name)
        self.staff_id = staff_id

    def info(self):
        return "staff: " + self.get_name() + ", staffID:"+ str(self.staff_id)

class Manager(Person):
    """
    Child class of person class
    """
    def __init__(self, name, position):
        Person.__init__(self, name)
        self.position = position

    def info(self):
        return "Manager: " + self.get_name() + ", position:"+ str(self.position)

worker1 = Employee("Ram Bahadur", 1111)
worker2 = Employee("Nir kumari", 2222)
cfo = Manager("Anita Saili", "CFO")
print(worker1.info())
print(worker2.info())
print(cfo.info())

# %% [markdown]
# ### PP 1
# Construct class Student that has following functionalities.
# This student took quizzes for English, mathematics and science, and the quiz scores are given as inputs. Generate instances by using this class. This class has the following attributes and actions.
#
#
# **attributes**
#
# ```
# name : student name stored in string type.
# student_id : student ID such as s2020001 stored in 8-digit integers.
# eng_quiz : student’s English quiz core stored in list format.
# math_quiz : student’s math quiz score stored in list format. science_quiz : student’s science quiz score stored in list format.
# ```
#
# **actions(methods)**
#
# ```
# __init__ : initializes with the student’s name and studentID.
# __str__ : returns the student’s name, studentID and quiz scores as strings
#
# set_eng_quiz : sets the student’s English quiz.
# set_math_quiz : sets the student’s mathematics quiz.
# set_science_quiz : sets the student’s science quiz.
#
# get_name : returns the student’s name
# get_student_id : returns the studentID
# get_eng_quiz : returns the student’s English quiz
# get_math_quiz : returns the student’s math quiz
# get_science_quiz : returns the student’s science quiz
# get_total_score : returns the student’s total quiz score
# get_avg_score : returns the student’s average quiz score
# ```
#
# **Output Example**
#
# ```
# Enter the student’s name : David Doe
# Enter the student’s ID : 20213093
# Enter the student’s English quiz score : 90
# Enter the student’s mathematics quiz score : 95
# Enter the student’s science quiz score : 100
# Name : David Doe, ID : 20213093
# English quiz score : 90, Mathematics quiz score : 95
# Science quiz score : 100,
# Total : 285, Average : 95.0
# ```
